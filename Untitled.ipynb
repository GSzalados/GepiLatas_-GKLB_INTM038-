# %% [markdown]
# A következő library-kat használtam

# %%
import cv2
import numpy as np
import imutils
import pytesseract as tess
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# dsf
